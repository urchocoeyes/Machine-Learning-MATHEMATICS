# %% [markdown]
# (HW3)=
# # HW3
#
# ## Task 3.1 (0.5 points)
#
# Express $\sigma''(x)$ in terms of $\sigma(x)$ where $\sigma(x) = \frac 1{1 + e^{-t}}$ — sigmoid function. Find all $x$ for which $\sigma''(x) = 0$. Also find intervals on which sigmoid is convex/concave.
#
# ### MY SOLUTION
# To find $\sigma''(x)$ (second derivative of sigmoid function), we need to find $\sigma'(x)$ (first derivative of sigmoid function), and again differentiate it:
# $$
# \sigma'(x) = \frac {d}{dx}(\frac {1}{1 + e^{-x}})
# $$
# We can rewrite as:
# $$
# \sigma'(x) = \frac {d}{dx} (1 + e^{-x})^{-1}
# $$
# By power rule, derivative of **n-th** power is defined as:
# $$
# \frac {d}{dx} (x^{n}) = n(x^{n-1})
# $$
# We have power of **-1** and I will use **chain rule**, since, we have inside also exponential function:
# $$
# \sigma'(x) = -1(1 + e^{-x})^{-2} \cdot (1 + e^{-x})'
# \\
# = -1(1 + e^{-x})^{-2} \cdot e^{-x} \cdot (-x)'
# \\
# = -1(1 + e^{-x})^{-2} \cdot e^{-x} \cdot -1
# \\
# =\frac{e^{-x}}{(1 + e^{-x})^{2}}
# $$
# Finding $\sigma''(x)$:
# $$
# \sigma''(x) = \frac {d}{dx} (\frac{e^{-x}}{(1 + e^{-x})^{2}})
# $$
# Using quotient rule and **chain rule**:
# $$
# \sigma''(x) = \frac {(e^{-x})'(1+e^{-x})^{2} - e^{-x}((1 + e^{-x})^{2})'}{((1+e^{-x})^{2})^{2}}
# \\
# = \frac {e^{-x} \cdot (-1) \cdot (1+e^{-x})^{2} - e^{-x}\cdot 2(1+e^{-x})\cdot e^{-x} \cdot (-1)}{(1+e^{-x})^4}
# \\
# = \frac {-e^{-x}(1+2e^{-x}+e^{-2x})+2e^{-2x}(1+e^{-x})}{(1+e^{-x})^4}
# \\
# = \frac {-e^{-x}-2e^{-2x}-e^{-3x}+2e^{-2x}+2e^{-3x}}{(1+e^{-x})^4}
# \\
# =\frac {-e^{-x}+e^{-3x}}{(1+e^{-x})^4}
# \\
# $$
#
# $$
# \\
# \sigma''(x)=\frac {-e^{-x}+e^{-3x}}{(1+e^{-x})^4}
# $$
# Finding all $x$ for which $\sigma''(x)=0$:
# $$
# \sigma''(x)=\frac {-e^{-x}+e^{-3x}}{(1+e^{-x})^4} =0
# $$
# Denominator can not be zero:
# $$
# (1+e^{-x})^{4} \neq 0
# \\
# (1+e^{-x}) \neq 0
# \\
# e^{-x} \neq -1
#
# $$
# We can not find $x$ from this equation, so, we can not define any **REAL** $x$ for **which**, this equation will be $0$. <br>
# Look at numerator:
# $$
# -e^{-x}+e^{-3x}=0
# \\
# -e^{-x}(1-e^{-2x})=0
# \\
# -e^{-x} = 0 \quad (1-e^{-2x})=0
# $$
# From equation $-e^{-x}=0$ we can not find any **REAL** $x$.
# <br>
# From equation $(1-e^{-2x})=0$ we can find **REAL** $x$:
# $$
# (1-e^{-2x})=0
# \\
# e^{-2x}=1
# \\
# -2x = 0
# \\
# x = 0
# $$
# **For $x=0$: $\sigma''(x)=0$**
# <br>
# **Finding intervals on which sigmoid is convex/concave:** <br>
# To find when function is **convex**: $f''(x)>0$
# $$
# \sigma''(x)=\frac {-e^{-x}+e^{-3x}}{(1+e^{-x})^4}>0
# $$
# Denominator can not be equal to zero and denominator is **positive** for all $x$, since, it is powered by 4(even number gives positive result):
# $$
# (1+e^{-x})^4 \neq 0
# \\
# (1+e^{-x})^4 > 0
# $$
# Numerator should be greater than zero for all $x$:
# $$
# -e^{-x}+e^{-3x} > 0
# \\
# -e^{-x}(1-e^{-2x})>0
# $$
# Multiply both sides by (-1):
# $$
# e^{-x}(1-e^{-2x})<0
# $$
# To satisfy condition that "multiplication of **positive** and **negative** will be **negative**"
# $$\begin{cases} e^{-x}<0
# \\
# (1-e^{-2x})>0
# \end{cases} \quad (1)
# \\
# \begin{cases}
# e^{-x}>0
# \\
# (1-e^{-2x})<0
# \end{cases} \quad (2)
# $$
# If we will solve first (1)-st system:
# $$
# e^{-x}<0
# \\
# x \notin \mathbb{R}
# \\
# (1-e^{-2x}) > 0
# \\
# -e^{-2x}>-1
# \\
# e^{-2x}<1
# \\
# e^{-2x} < e^{0}
# \\
# -2x<0
# \\
# x >0
# $$
# Answer for (1)-st system:
# $$
# \begin{cases} e^{-x}<0
# \\
# (1-e^{-2x})>0
# \end{cases}  =
# \begin{cases}
# x \notin \mathbb{R}
# \\
# x \in (0, +\infty)
# \end{cases}
# $$
# Since, $x \notin \mathbb{R}$ and $x>0$, for (1)-st system , solution is considered as $x \notin \mathbb{R}$.<br>
# If we will solve second (2)-nd system:
# $$
# e^{-x}>0
# \\
# x \in \mathbb{R}
# \\
# (1-e^{-2x})<0
# \\
# -e^{-2x}<-1
# \\
# e^{-2x}>1
# \\
# e^{-2x}>2^{0}
# \\
# -2x>0
# \\
# x<0
# $$
# Answer for (2)-nd system:
# $$
# \begin{cases}
# e^{-x}>0
# \\
# (1-e^{-2x})<0
# \end{cases} =
# \begin{cases}
# x \in \mathbb{R}
# \\
# x \in (-\infty, 0)
# \end{cases}
#
# $$
# Since, $x \in \mathbb {R}$ and $x<0$, for (2)-nd system, solution is considered as $x \in (-\infty, 0)$. **Sigmoid function is convex on interval: $(-\infty, 0)$**.
# To find when function is **concave:**
# $f''(x)<0$
# $$
# \sigma''(x) = \frac {-e^{-x}+e^{-3x}}{(1+e^{-x})^{4}} < 0
# $$
# Denominator can not be equal to zero and denominator is **positive** for all $x$, since, it is powered by 4(even number gives positive result):
# $$
# (1+e^{-x})^4 \neq 0
# \\
# (1+e^{-x})^4 > 0
# $$
# Numerator should be less than zero for all x:
# $$
# -e^{-x}+e^{-3x}<0
# \\
# -e^{-x}(1-e^{-2x})<0
# \\
# $$
# Multiply both sides by (-1) and change sign:
# $$
# e^{-x}(1-e^{-2x})>0
# $$
# To satisfy condition that "multiplication of **positive** and **positive** will be ***positive*** or multiplication of **negative** and **negative** will be ***positive***":
# $$
# \begin{cases}
# e^{-x}>0
# \\
# (1-e^{-2x})>0
# \end{cases} \quad (3)
# \\
# \begin{cases}
# e^{-x}<0
# \\
# (1-e^{-2x})<0
# \end{cases} \quad (4)
# $$
# If we will solve third (3)-rd system:
# $$
# e^{-x}>0
# \\
# x \in \mathbb{R}
# \\
# (1-e^{-2x})>0
# \\
# -e^{-2x} > -1
# \\
# e^{-2x}<1
# \\
# e^{-2x}<e^{0}
# \\
# -2x < 0
# \\
# x > 0
# $$
# Answer for (3)-rd system:
# $$
# \begin{cases}
# e^{-x}>0
# \\
# (1-e^{-2x})>0
# \end{cases} = \begin{cases}
# x \in \mathbb{R}
# \\
# x \in (0, +\infty)
# \end{cases}
# $$
# Since, $x \in \mathbb{R}$ and $x > 0$, for (3)-rd system, solution is considered as $x \in (0, +\infty)$. <br>
# If we will solve fourth (4-th) system:
# $$
# e^{-x}<0
# \\
# x \notin \mathbb{R}
# \\
# (1-e^{-2x})<0
# \\
# -e^{-2x}<-1
# \\
# e^{-2x}>1
# \\
# e^{-2x}>e^{0}
# \\
# -2x > 0
# \\
# x < 0
# $$
# Answer for (4)-th system:
# $$
# \begin{cases}
# e^{-x}<0
# \\
# (1-e^{-2x})<0
# \end{cases} =
# \begin{cases}
# x \notin \mathbb{R}
# \\
# x \in (-\infty, 0)
# \end{cases}
# $$
# Since, $x \notin \mathbb{R}$ and $x < 0$, for (4)-th system, solution is considered as $x \notin \mathbb{R}$. **Sigmoid function is concave on interval: $(0, +\infty)$.**

# %% [markdown]
# ## Task 3.2 (0.5 points)
#
# Let $\boldsymbol X \in \mathbb R^{m\times n}$ and $f(\boldsymbol X) = \vert \boldsymbol X \vert^k$, $k\in\mathbb N$. Find $\nabla f(\boldsymbol X)$.
#
# ### MY SOLUTION
#
# $$ f(\mathbf{X}) = |\mathbf{X}|^k $$
#
# Where $ |\mathbf{X}| $ denotes the absolute value taken element-wise, and $ k $ is a positive integer.
#
# To find the gradient of $ f(\mathbf{X}) $, we'll differentiate it with respect to each element of $ \mathbf{X} $ (each $ X_{ij} $).
#
# The gradient with respect to $\boldsymbol X$ can be calculated using the chain rule. We have:
#
# $$ \nabla f(\mathbf{X}) = k \cdot \mathbf{|\boldsymbol X |}^{k-1} \cdot \nabla \mathbf{|X|} $$
#
# Let;s find $\nabla \mathbf{|X|} $, which represents the gradient of $ |\mathbf{X}| $ with respect to $\mathbf{X}$.
#
# The absolute value function applied to each element is a piecewise function, but its derivative is well-defined. The derivative of the absolute value function $ |\boldsymbol X|$  with respect to its element $x$ is:
#
# $$ \frac{d}{dx} |x| = \begin{cases} 1 & \text{if } x > 0 \\ -1 & \text{if } x < 0 \\ \text{undefined} & \text{if } x = 0 \end{cases} $$
#
# So, the derivative is either $ 1 $ or $-1 $ depending on the sign of $ x $, and it's not defined at $ x = 0 $.
#
# $$ \partial |X_{ij}| = \begin{cases} 1 & \text{if } X_{ij} > 0 \\ \text {undefined} & \text{if } X_{ij} = 0 \\ -1 & \text{if } X_{ij} < 0 \end{cases} $$
#
# Putting it all together, we have:
#
# $$ \nabla f(\mathbf{X})_{ij} =
#  k \cdot |\mathbf{X}_{ij}|^{k-1} \cdot \begin{cases} 1 & \text{if } \mathbf{X}_{ij} > 0 \\ -1 & \text{if } \mathbf{X}_{ij} < 0 \end{cases} $$
#
# This expression represents the gradient of $ f(\mathbf{X}) $ with respect to each element of $ \mathbf{X} $.

# %% [markdown]
# ## Task 3.3 (2 points)
#
# Let $\boldsymbol A \in \mathbb R^{n\times n}$ be a symmetric matrix and
#
# $$
# f(\boldsymbol x) = \frac{\boldsymbol x^\mathsf{T} \boldsymbol{Ax}}{\boldsymbol x^\mathsf{T} \boldsymbol x}, \quad \boldsymbol x \in \mathbb R^n.
# $$
#
# (a) (**1 point**) Calculate $\nabla f(\boldsymbol x)$ and prove that $\nabla f(\boldsymbol x) = \boldsymbol 0$ iff $\boldsymbol x$ is an eigenvector of $\boldsymbol A$.
#
# ### MY SOLUTION for (a):
# $$
# \nabla f(\boldsymbol x) = \nabla (\frac{\boldsymbol x^\mathsf{T} \boldsymbol{Ax}}{\boldsymbol x^\mathsf{T} \boldsymbol x})
# $$
# Using the quotient rule for differentiation:
# $$
# \nabla f(\boldsymbol x) = \frac{\nabla (\boldsymbol x^\mathsf{T} \boldsymbol A \boldsymbol x)(\boldsymbol x^\mathsf{T}\boldsymbol x) - (\boldsymbol x^\mathsf{T} \boldsymbol A \boldsymbol x)\nabla(\boldsymbol x^\mathsf{T}\boldsymbol x)}{(\boldsymbol x^\mathsf{T} \boldsymbol x)^2}
# $$
# Computing gradients separately:
# $$
# 1. \nabla (\boldsymbol x^\mathsf{T} \boldsymbol A \boldsymbol x)
# \\
# 2. \nabla (\boldsymbol x ^ \mathsf{T} \boldsymbol x)
# $$
# Computing $\nabla (\boldsymbol x^\mathsf{T} \boldsymbol A \boldsymbol x)$, using formula of **product rule**, differentiation with respect to $\boldsymbol x$:
# $$
# \nabla (\boldsymbol x^\mathsf{T} \boldsymbol A \boldsymbol x) = \nabla (\boldsymbol x^\mathsf{T})\boldsymbol A\boldsymbol x + \boldsymbol x^\mathsf{T} \nabla(\boldsymbol A\boldsymbol x)
# \\
# \nabla(\boldsymbol x ^ \mathsf{T}) = 1
# \\
# \nabla(\boldsymbol A \boldsymbol x) = \boldsymbol A
# \\
# \nabla(\boldsymbol x^\mathsf{T}\boldsymbol A\boldsymbol x) = \boldsymbol A \boldsymbol x + \boldsymbol x^\mathsf{T}\boldsymbol A = \boldsymbol A \boldsymbol x + \boldsymbol A^\mathsf{T} \boldsymbol x = 2\boldsymbol A\boldsymbol x
# $$
# Since, $\boldsymbol A$ is symmetric matrix: $\boldsymbol A^{\mathsf{T}} = \boldsymbol A$.
# <br>
# Computing $\nabla( \boldsymbol x^{\mathsf{T}}
# \boldsymbol x)$, using formula of **product rule**, differentiation with respect to $\boldsymbol x$:
# $$
# \nabla(\boldsymbol x^{\mathsf{T}}
# \boldsymbol x) = \nabla \boldsymbol x^{T} \boldsymbol x + \boldsymbol x ^{T}\nabla \boldsymbol x = \boldsymbol x + \boldsymbol x^{T} = 2 \boldsymbol x
# $$
# Substituting values and finding gradient function:
# $$
# \nabla f(\boldsymbol x) = \frac{\nabla (\boldsymbol x^\mathsf{T} \boldsymbol A \boldsymbol x)(\boldsymbol x^\mathsf{T}\boldsymbol x) - (\boldsymbol x^\mathsf{T} \boldsymbol A \boldsymbol x)\nabla(\boldsymbol x^\mathsf{T}\boldsymbol x)}{(\boldsymbol x^\mathsf{T} \boldsymbol x)^2} =
# \\
# \frac{(2 \boldsymbol A \boldsymbol x) (\boldsymbol x^{T}\boldsymbol x) - (\boldsymbol x^{T}\boldsymbol A \boldsymbol x)(2\boldsymbol x)}{(\boldsymbol x^T\boldsymbol x )^2} =
# \\
# \frac{2 \boldsymbol A \boldsymbol x \boldsymbol x^{T}\boldsymbol x - \boldsymbol x^{T}\boldsymbol A \boldsymbol x2\boldsymbol x}{(\boldsymbol x^T\boldsymbol x )^2} =
# \\
# \frac{2 \boldsymbol A \boldsymbol x \boldsymbol x^{T}\boldsymbol x - 2 \boldsymbol A \boldsymbol x \boldsymbol x^{T}\boldsymbol x}{(\boldsymbol x^T\boldsymbol x )^2} = 0.
# $$
# **Gradient of function is:**
# $$
# \nabla f(\boldsymbol x) = 0.
# $$
# **Proving of**: $\nabla f(\boldsymbol x) = 0$ iff $\boldsymbol x$ is an eigenvector of $\boldsymbol A$:
# Let $\lambda$ be the eigenvalue associated with the eigenvector $\boldsymbol x$. By definition:
# $$
# \boldsymbol A \boldsymbol x = \lambda \boldsymbol x
# $$
# Thus, function itself finds eigenvalue of corresponding eigenvector:
# $$
# f(\boldsymbol x) = \frac{\boldsymbol x^\mathsf{T} \boldsymbol{Ax}}{\boldsymbol x^\mathsf{T} \boldsymbol x} = \lambda
# \\
# $$
# $$
# \boldsymbol x^\mathsf{T} \boldsymbol{Ax} = \lambda \boldsymbol x^\mathsf{T} \boldsymbol x
# $$
# I've shown above that $\nabla f(\boldsymbol x) = 0$, it means we take the derivative of some constant, since $\frac{d}{dx}C = 0$, where $C$ is constant. And that constant that is result of function $f(\boldsymbol x) = \frac{\boldsymbol x^\mathsf{T} \boldsymbol{Ax}}{\boldsymbol x^\mathsf{T} \boldsymbol x}$ is eigenvalue.
# If $\nabla f(\boldsymbol x) = 0$, then $\boldsymbol x^\mathsf{T} \boldsymbol{Ax} = \lambda \boldsymbol x^\mathsf{T} \boldsymbol x$ with $\lambda = \frac{\boldsymbol x^\mathsf{T} \boldsymbol{Ax}}{\boldsymbol x^\mathsf{T} \boldsymbol x} \Rightarrow \boldsymbol A\boldsymbol x = \lambda \boldsymbol x $ therefore $\boldsymbol x $  is an eigenvector of $\boldsymbol A$.
#
# (b) (**1 point**) Prove that if $\boldsymbol A$ is positive definite then
# $$
# \max\limits_{\boldsymbol x \ne \boldsymbol 0} f(\boldsymbol x) = \lambda_{\max}(\boldsymbol A), \quad
# \min\limits_{\boldsymbol x \ne \boldsymbol 0} f(\boldsymbol x) = \lambda_{\min}(\boldsymbol A)
# $$
#
# ### MY SOLUTION for (b):
# A matrix is positive definite if it's symmetric and all its eigenvalues are positive. Let $\lambda_{\max}$ be the maximum eigenvalue and $\lambda_{\min}$ be the minimum eigenvalue. Since, $\boldsymbol A$ is symmetric, it has property:
# eigenvectors corresponding to the eigenvalues are **orthogonal** ,every symmetric matrix has an orthonormal set of eigenvectors. Let $\boldsymbol x_1, \boldsymbol x_2, ..., \boldsymbol x_{n}$ be the eigenvectors corresponding to eigenvalues $\lambda_1, \lambda_2,..., \lambda_n$. <br>
# Considering the eigenvector $\boldsymbol x_{\max}$ corresponding to $\lambda_{\max}$:
# $$
# f(\boldsymbol x_{\max}) = \frac{\boldsymbol x_{\max}^{\mathsf T}\boldsymbol A \boldsymbol x_{\max}}{\boldsymbol x_{\max}^{\mathsf T}\boldsymbol x_{\max}} = \lambda_{max}
# \\
# $$
# $$
# \boldsymbol x_{\max}^{\mathsf T}\boldsymbol x_{\max} = 1
# $$
# $\boldsymbol x_{\max}^T$ is row, $\boldsymbol A$ is matrix, $\boldsymbol x_{\max}$ is column. As row multiplied by matrix results **row**, after that, **row** multiplied by column results **scalar(number)**, it ensures that output of expression: $\boldsymbol x_{\max}^{\mathsf T}\boldsymbol A \boldsymbol x_{\max}$ will be **scalar**, that is ***eigenvalue***.
# <br>
# Even if we cancel $\boldsymbol x_{\max}^{\mathsf T}$ we will get eigen-equation:
# $$
# \boldsymbol A \boldsymbol x_{\max} = \lambda_{\max}\boldsymbol x_{\max}
# $$
# Similarly, consider the eigenvector $\boldsymbol x_{\min}$ corresponding to $\lambda_{\min}$:
# $$
# f(\boldsymbol x_{\min}) = \frac{\boldsymbol x_{\min}^{\mathsf T}\boldsymbol A \boldsymbol x_{\min}}{\boldsymbol x_{\min}^{\mathsf T}\boldsymbol x_{\min}} = \lambda_{\min}
# $$
# Since, $\lambda_{\max}$ and $\lambda_{\min}$ are the maximum and minimum eigenvalues respectively:
# $$
# \max\limits_{\boldsymbol x \ne \boldsymbol 0} f(\boldsymbol x) = \lambda_{\max}
# \\
# \min\limits_{\boldsymbol x \ne \boldsymbol 0} f(\boldsymbol x) = \lambda_{\min}
# $$

# %% [markdown]
# ## Task 3.4 (1 point)
#
# 4. Find
#
#     $$
#         \min\limits_{\boldsymbol X} \Vert \boldsymbol{AX} - \boldsymbol B  \Vert_F^2, \quad \boldsymbol A \in \mathbb R^{k\times m},\quad \boldsymbol B \in \mathbb R^{k\times n},\quad \mathrm{rank}(\boldsymbol A) = m.
#     $$
#
# ### MY SOLUTION:
# The Frobenius norm of a matrix is a way to measure the "size" or "magnitude" of a matrix. For a matrix $\boldsymbol A\boldsymbol X -\boldsymbol B$ with elements $(\boldsymbol A\boldsymbol X -\boldsymbol B)_{ij}$, the Frobenius norm, denoted as $\Vert\boldsymbol A\boldsymbol X -\boldsymbol B\Vert_{F}$, is defined as the square root of the sum of the squares of all the elements:
# $$
# \Vert\boldsymbol A \boldsymbol X - \boldsymbol B\Vert_{F}= \sqrt{\sum_{i=1}^k\sum_{j = 1}^n(\boldsymbol A \boldsymbol X - \boldsymbol B)_{ij}^2}
# $$
# Where $k$ - number of rows, after finding difference,
# <br>
# $n$ - number of columns, after finding difference.
# <br>
# We are aimed to find such $\boldsymbol X$ that minimizes the Frobenius norm of the difference $\boldsymbol A\boldsymbol X -\boldsymbol B$:
# $$
# \min\limits_{\boldsymbol X}\Vert \boldsymbol A \boldsymbol X - \boldsymbol B \Vert_F^2 = \min\limits_{\boldsymbol X}\sum_{i=1}^{k}\sum_{j=1}^{n}(\boldsymbol A \boldsymbol X - \boldsymbol B )_{ij}^{2}
# $$
# To minimize the $\boldsymbol X$, we need to take the derivative of $\Vert \boldsymbol A \boldsymbol X - \boldsymbol B \Vert_{F}^2$  with respect to $\boldsymbol X$ and set it to 0:
# <br>
# $$
# \\
# \frac{\partial \Vert \boldsymbol A \boldsymbol X - \boldsymbol B \Vert_{F}^2}{\partial \boldsymbol X}
# =
# \\
# \frac {\partial}{\partial \boldsymbol X} \sum_{i = 1}^k\sum_{j=1}^n(\boldsymbol A \boldsymbol X - \boldsymbol B)_{ij}^2 =
# \\
# \sum_{i=1}^k\sum_{j=1}^n\frac{\partial}{\partial \boldsymbol X}(\boldsymbol A\boldsymbol X - \boldsymbol B)_{ij}^2 =
# \\
# \sum_{i=1}^k
# \sum_{j=1}^n 2(\boldsymbol A\boldsymbol X - \boldsymbol B)_{ij}\frac{\partial}{\partial \boldsymbol X}(\boldsymbol A\boldsymbol X - \boldsymbol B)_{ij} =
# \\
# 2 \sum_{i=1}^k\sum_{j=1}^n(\boldsymbol A\boldsymbol X-\boldsymbol B)_{ij}(\boldsymbol A)_{ij}
# $$
# Since, $\boldsymbol B$ and $\boldsymbol A$ are treated as constants for partial derivative with respect to $\boldsymbol X$.
# **The derivative of $\Vert \boldsymbol A \boldsymbol X - \boldsymbol B \Vert_{F}^2$  with respect to $\boldsymbol X:$**
# $$
# \frac{\partial \Vert \boldsymbol A \boldsymbol X - \boldsymbol B \Vert_{F}^2}{\partial \boldsymbol X} = 2 \sum_{i=1}^k\sum_{j=1}^n(\boldsymbol A\boldsymbol X-\boldsymbol B)_{ij}(\boldsymbol A)_{ij}
# $$
# Set this derivative to 0 in order to find $\boldsymbol X$:
# $$
# 2 \sum_{i=1}^k\sum_{j=1}^n(\boldsymbol A\boldsymbol X-\boldsymbol B)_{ij}(\boldsymbol A)_{ij} = 0
# $$
# $2$ and $(\boldsymbol A)_{ij}$ are like "constants", in result with right hand zero. We can divide both sides by $1/2 (\boldsymbol A)_{ij}$. With remaining part after deletion: <br>
# To solve the equation $\sum_{i=1}^k\sum_{j=1}^n(\boldsymbol A\boldsymbol X-\boldsymbol B)_{ij} = 0$ for $\boldsymbol X$, we can expand the matrix multiplication $\boldsymbol A\boldsymbol X$ and then isolate $\boldsymbol X$.
#
# Given that $\boldsymbol A$ is a $k \times m$ matrix, $\boldsymbol X$ is an $m \times n$ matrix, and $\boldsymbol B$ is a $k \times n$ matrix, the resulting matrix $(\boldsymbol A\boldsymbol X-\boldsymbol B)$ will be a $k \times n$ matrix.
#
# Expanding the summation, we have:
#
# $$
# \sum_{i=1}^k \sum_{j=1}^n(\boldsymbol A\boldsymbol X-\boldsymbol B)_{ij} = \sum_{i=1}^k\sum_{j=1}^n(\boldsymbol A\boldsymbol X)_{ij} - \sum_{i=1}^k\sum_{j=1}^n \boldsymbol B_{ij}
# $$
#
# Now, $(\boldsymbol A\boldsymbol X)_{ij}$ is the $ij$-th entry of the matrix $\boldsymbol A\boldsymbol X$, which is the result of the matrix multiplication of $\boldsymbol A$ and $\boldsymbol X$. So, it is:
#
# $$
# (\boldsymbol A\boldsymbol X)_{ij} = \sum_{l=1}^m \boldsymbol A_{il} \boldsymbol X_{lj}
# $$
#
# Substituting this back into the equation, we get:
#
# $$
# \sum_{i=1}^k\sum_{j=1}^n \left(\sum_{l=1}^m \boldsymbol A_{il} \boldsymbol X_{lj}\right) - \sum_{i=1}^k\sum_{j=1}^n \boldsymbol B_{ij} = 0
# $$
#
# Now we can distribute the summation:
#
# $$
# \sum_{i=1}^k\sum_{l=1}^m \sum_{j=1}^n \boldsymbol A_{il} \boldsymbol X_{lj} - \sum_{i=1}^k\sum_{j=1}^n \boldsymbol B_{ij} = 0
# $$
#
# Isolate $\boldsymbol X$:
#
# $$
# \sum_{i=1}^k\sum_{l=1}^m\sum_{j=1}^n \boldsymbol A_{il}\boldsymbol X_{lj}  - \sum_{i=1}^k\sum_{j=1}^n \boldsymbol B_{ij} = 0
# \\
# (\sum_{i=1}^k\sum_{l=1}^m \boldsymbol A_{il}) (\sum_{l=1}^m\sum_{j=1}^n \boldsymbol X_{lj})= \sum_{i=1}^k\sum_{j=1}^n \boldsymbol B_{ij}
# \\
# $$
# if rank of $\boldsymbol A$ is equal to
# $m$ , it means that all
# $m$ rows of this matrix are linearly independent, and thus it spans an
# $m$-dimensional space within the
# $k$-dimensional space it exists in. So, although it's not invertible in the traditional sense (because it's not square), it's invertible from the perspective of its columns, allowing it to be left-invertible. Matrix $\boldsymbol A$ has **full column rank**. Since, all columns have pivots, there is **no free variables.** The pseudo-inverse $\boldsymbol A^{+}$  of an m × n matrix A is an extension of the inverse of a square matrix to non-square matrices and to singular (i.e. non-invertible) square matrices.The pseudo-inverse matrix $\boldsymbol A^+$ is an n × m matrix with the following properties:
#
# If m ≥ n, then $\boldsymbol A^ T\boldsymbol A$ is invertible and $\boldsymbol A^+ = (\boldsymbol A^T\boldsymbol A)^{-1} \boldsymbol A^{T}$ and so $\boldsymbol A^+ \boldsymbol A = I$, i.e. $\boldsymbol A^+$ is a left inverse of $\boldsymbol A$.
# If m ≤ n, then $\boldsymbol A\boldsymbol A^T$ is invertible and $A^+ = A^T(AA^T)^{–1}$ and so $AA^+ = I$, i.e. $A^+$ is a right inverse of $A$.The homogenous system $\sum_{i=1}^k\sum_{l=1}^m\sum_{j=1}^n \boldsymbol A_{il}\boldsymbol X_{lj}  - \sum_{i=1}^k\sum_{j=1}^n \boldsymbol B_{ij} = 0$ has trivial solutions only.
# Let's denote for simplicity:
# $$
# \boldsymbol A = \sum_{i=1}^k\sum_{l=1}^m \boldsymbol A_{il}
# $$
# So, we have two cases:
# 1) if m >= n:
# $$
# \boldsymbol A^+ = (\boldsymbol A^T\boldsymbol A)^{-1} \boldsymbol A^{T}
# \\
# \boldsymbol A^+\boldsymbol A = \boldsymbol I
# $$
#
# 2) if m <= n:
# $$
# \boldsymbol A^+ = \boldsymbol A^T(\boldsymbol A\boldsymbol A^T)^{–1}
# \\
# \boldsymbol A\boldsymbol A^+ = \boldsymbol I
# $$
#
# **Original equation**:
# $$
# (\sum_{i=1}^k\sum_{l=1}^m \boldsymbol A_{il}) (\sum_{l=1}^m\sum_{j=1}^n \boldsymbol X_{lj})= \sum_{i=1}^k\sum_{j=1}^n \boldsymbol B_{ij}
#
# \\
#
# \boldsymbol A (\sum_{l=1}^m\sum_{j=1}^n \boldsymbol X_{lj})= \sum_{i=1}^k\sum_{j=1}^n \boldsymbol B_{ij}
# $$
#
# **The answers will be:** <br>
#
# **For m >= n**:
# $$
# (\boldsymbol A^T\boldsymbol A)^{-1} \boldsymbol A^{T} \boldsymbol A
# \sum_{l=1}^m\sum_{j=1}^n \boldsymbol X_{lj} =  (\boldsymbol A^T\boldsymbol A)^{-1} \boldsymbol A^{T} \sum_{i=1}^k\sum_{j=1}^n \boldsymbol B_{ij}
# \\
# \sum_{l=1}^m\sum_{j=1}^n \boldsymbol X_{lj} = (\boldsymbol A^T\boldsymbol A)^{-1} \boldsymbol A^{T} \sum_{i=1}^k\sum_{j=1}^n \boldsymbol B_{ij}
# \\
# \boldsymbol X = (\boldsymbol A^T\boldsymbol A)^{-1} \boldsymbol A^{T} \sum_{i=1}^k\sum_{j=1}^n \boldsymbol B_{ij}
# $$
# where
# $$
# \boldsymbol A = \sum_{i=1}^k\sum_{l=1}^m \boldsymbol A_{il}
# $$
# **For m < n**:
# Since, pseudo inverse of $\boldsymbol A$, that is $\boldsymbol A^+$ has size $m \times k$, and $\boldsymbol A$ has size $k \times m$. When we multiply $\boldsymbol A \cdot \boldsymbol A^+$ , result will be identity matrix with size $k \times k$, and we cannot multiply matrix with size $k \times k$ with matrix of size $m \times n$:
# $$
# \boldsymbol A \boldsymbol A^T(\boldsymbol A\boldsymbol A^T)^{–1}
# \sum_{l=1}^m\sum_{j=1}^n \boldsymbol X_{lj} = \sum_{i=1}^k\sum_{j=1}^n \boldsymbol B_{ij} \boldsymbol A^T(\boldsymbol A\boldsymbol A^T)^{–1}
# $$
#  ***Solution only true for the case when **m >= n*****:
#  $$
#  \boldsymbol X = (\boldsymbol A^T\boldsymbol A)^{-1} \boldsymbol A^{T} \sum_{i=1}^k\sum_{j=1}^n \boldsymbol B_{ij}
# $$
# where
# $$
# \boldsymbol A = \sum_{i=1}^k\sum_{l=1}^m \boldsymbol A_{il}
# $$
# Note: everywhere I have <= and >= with equals (=) sign, this equal sign, when matrix has same number of rows and columns.
